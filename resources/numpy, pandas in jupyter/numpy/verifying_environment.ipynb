# %%
import sys
import numpy as np

print("--- Environment Verification ---")
print(f"Python executable path: {sys.executable}")
print(f"Python Version: {sys.version}")
print(f"NumPy Version Installed: {np.__version__}")

# Quick test matrix initialization to verify C-extensions function on Rosetta
try:
    test_array = np.array([[1, 2], [3, 4]])
    print(f"\nNumPy Test Success! Matrix Shape: {test_array.shape}")
except Exception as e:
    print(f"\nNumPy Initialization Error: {e}")
# Out:
# --- Environment Verification ---
# Python executable path: /opt/miniconda3/envs/cs231n_env/bin/python
# Python Version: 3.7.16 (default, Jan 17 2023, 09:28:58)
# [Clang 14.0.6 ]
# NumPy Version Installed: 1.21.5
#
# NumPy Test Success! Matrix Shape: (2, 2)
